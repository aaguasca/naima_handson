# %% [markdown]
# # RS Oph
# RS Oph is a binary system that undergoes recurrent **nova** eruption every ~15 years. The last one was in August 2021 and was extensively followed up at gamma rays. RS Oph is the first nova detected at gamma rays above 100 GeV.
#
# In this notebook, we will model its gamma-ray emission.

# %% [markdown]
# <img src="../data/images/RSOph.png" alt="RSOph" width="600">
#
# Credit: David A.Hardy / www.astroart.org & PPARC.

# %%
# imports
from astropy.table import Table
import astropy.units as u
import naima
import numpy as np
import matplotlib.pyplot as plt
import subprocess
from IPython.display import Image
import matplotlib.animation as animation
import naima
from IPython.display import HTML
from astropy.visualization import quantity_support
import os, sys
# Add the project root directory to the Python path to ensure imports work correctly
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# %% [markdown]
# # Display the SED

# %%
# Import necessary libraries
from astropy.table import Table  # For reading data tables
import matplotlib.pyplot as plt  # For plotting
import numpy as np  # For numerical operations
import matplotlib.animation as animation  # For animation
from IPython.display import HTML  # To display the animation

# Load the SED data for each day
sed_day1 = Table.read('../data/RSOph/RSOph_day1_diff_flux.ecsv', format='ascii.ecsv')
sed_day2 = Table.read('../data/RSOph/RSOph_day2_diff_flux.ecsv', format='ascii.ecsv')
sed_day3 = Table.read('../data/RSOph/RSOph_day3_diff_flux.ecsv', format='ascii.ecsv')
sed_day4 = Table.read('../data/RSOph/RSOph_day4_diff_flux.ecsv', format='ascii.ecsv')

# Group the data tables for easy access
daily_data = [sed_day1, sed_day2, sed_day3, sed_day4]

# Define the corresponding days
days = [1, 2, 3, 4]

# Create a plot figure and axis
fig, ax = plt.subplots(figsize=(6, 4))

# Update function for the animation
def update(frame):
    """
    Update the plot for each frame of the animation.
    """
    ax.clear()  # Clear the previous plot
    
    # Loop through each group and plot data for the current frame (day)
    for i in np.unique(daily_data[frame]['group'].value):
        mask_group = daily_data[frame]['group'].value == i
        mask_ul = daily_data[frame]['ul'].value == True

        # Plot normal data points
        ax.errorbar(
            x=daily_data[frame]["energy"].value[~mask_ul & mask_group],
            y=daily_data[frame]["energy"].value[~mask_ul & mask_group]**2 *\
                  daily_data[frame]["flux"].value[~mask_ul & mask_group],
            yerr=daily_data[frame]["energy"].value[~mask_ul & mask_group]**2 *\
                  daily_data[frame]["flux_error"].value[~mask_ul & mask_group],
            color=naima.plot.color_cycle[i],
            marker="o", ls=""
        )

        # Plot upper limit data points
        ax.errorbar(
            x=daily_data[frame]["energy"].value[mask_ul & mask_group],
            y=daily_data[frame]["energy"].value[mask_ul & mask_group]**2 *\
                  daily_data[frame]["flux"].value[mask_ul & mask_group],
            yerr=daily_data[frame]["energy"].value[mask_ul & mask_group]**2 *\
                  daily_data[frame]["flux"].value[mask_ul & mask_group] * 0.3,
            color=naima.plot.color_cycle[i],
            marker="o", ls="", uplims=True
        )

    # Set plot details (titles, axis limits, labels)
    ax.set_title(f"Day {days[frame]} after eruption")
    ax.set_xlim((0.00006, 2.6))
    ax.set_ylim((5e-14, 2e-08))
    ax.set_xlabel("Energy (TeV)")
    ax.set_ylabel(f"E$^2$ d$\phi$/dE (erg cm$^{{-2}}$ s$^{{-1}}$)")
    ax.set_xscale("log")
    ax.set_yscale("log")
    plt.tight_layout()
    plt.close()

# Create the animation
ani = animation.FuncAnimation(fig, update, frames=len(daily_data), interval=1000, repeat=True)

# Save or display the animation
# ani.save("data_animation.gif", writer="pillow", fps=1)  # Uncomment to save as GIF

HTML(ani.to_jshtml())  # Display in Jupyter as JavaScript
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img8205d3ebfb0b4da5ba986587f4e40ff6">
#   <div class="anim-controls">
#     <input id="_anim_slider8205d3ebfb0b4da5ba986587f4e40ff6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim8205d3ebfb0b4da5ba986587f4e40ff6.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim8205d3ebfb0b4da5ba986587f4e40ff6.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select8205d3ebfb0b4da5ba986587f4e40ff6"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_8205d3ebfb0b4da5ba986587f4e40ff6"
#              >
#       <label for="_anim_radio1_8205d3ebfb0b4da5ba986587f4e40ff6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_8205d3ebfb0b4da5ba986587f4e40ff6"
#              checked>
#       <label for="_anim_radio2_8205d3ebfb0b4da5ba986587f4e40ff6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_8205d3ebfb0b4da5ba986587f4e40ff6"
#              >
#       <label for="_anim_radio3_8205d3ebfb0b4da5ba986587f4e40ff6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img8205d3ebfb0b4da5ba986587f4e40ff6";
#     var slider_id = "_anim_slider8205d3ebfb0b4da5ba986587f4e40ff6";
#     var loop_select_id = "_anim_loop_select8205d3ebfb0b4da5ba986587f4e40ff6";
#     var frames = new Array(4);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjEsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvc2/+5QAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAUCpJRE

# %% [markdown]
# The emission at gamma rays within the first four days after the eruption is variable!
#
# - The emission decreases at GeV
# - The emission increases at TeV

# %% [markdown]
# # Model fitting
#
# Although a complex modelization would be required to model the temporal evolution of the particles and physical parameters of the system involved in the gamma-ray emission of RS Oph and account for the gamma-gamma absorption by the photons of the photosphere, below we will use a simple model with naima for this task.
#
# Note that naima does not consider temporal evolution in the physical parameters. Therefore, we have to add it by hand. We will consider the parametrization in Acciari et al. 2022.
#
# <img src="../data/images/Schematic_model.png" alt="RSOph model" width="600">
#
# Source: Acciari, V. A., Ansoldi, S., Antonelli, L. A., et al. 2022, Nature Astronomy, 6, 689

# %% [markdown]
# # Hadronic model
#
# Hadronic stands for a model that only accounts for processes involving hadrons in the interactions to explain the gamma-ray emission. In this case, we will use the neutral pion decay radiative process.
#
# Note that secondary particles, e.g. electrons, can also produce gamma rays! We will not consider this possibility.

# %%
# %%writefile ../fit_results/RSOph/hadronic_model/RSOph_hadronic.py
# Magic command to write the content of the cell to a Python file

#imports
import astropy.units as u
import numpy as np 
import naima
from naima.models import ExponentialCutoffPowerLaw
from astropy.table import Table
import os

class PionDecayModel:
    """
    Define a model for the pion decay emission from a proton energy distribution
    following a power-law with exponential cut-off.
    
    The target proton density is parameterized as a function of the day
    after the nova explosion.
    """
    def __init__(self, day_value):
        # Initialize with the day after the nova explosion
        self.day_value = day_value

    def PionDecay(self, pars, data):
        """
        Define the particle distribution model, radiative model, and return model flux
        at the given energy values from data.

        Parameters:
        pars : array
            Parameters for the model (e.g., normalization, index, cutoff).
        data : Table
            The energy data for which flux needs to be calculated.
        
        Returns:
        flux : Quantity
            The calculated flux at the given energy values.
        """
        # Define particle distribution model with exponential cutoff
        ECPL = ExponentialCutoffPowerLaw(
            10 ** pars[0] / u.eV, 130 * u.GeV, pars[1], 10 ** pars[2] * u.GeV
        )

        # Define the pion decay model using the particle distribution and target density
        PP = naima.models.PionDecay(ECPL, nh=6.0e8 * (self.day_value / 3) ** (-3) * u.cm ** -3)

        # Return the flux for the given energy values
        return PP.flux(data, distance=2.45 * u.kpc)

def lnprior(pars):
    """
    Define a prior distribution for the model parameters.
    Limits the amplitude (norm) to positive values.

    Parameters:
    pars : array
        Parameters for the model.

    Returns:
    logprob : float
        The log probability of the parameters.
    """
    # Limit amplitude to positive domain (uniform prior)
    logprob = naima.uniform_prior(pars[0], 0, np.inf)
               
    return logprob


if __name__ == '__main__':
    # Read in the SED data for each day from CSV files
    sed_day1 = Table.read('../data/RSOph/RSOph_day1_diff_flux.ecsv', format='ascii.ecsv')
    sed_day2 = Table.read('../data/RSOph/RSOph_day2_diff_flux.ecsv', format='ascii.ecsv')
    sed_day3 = Table.read('../data/RSOph/RSOph_day3_diff_flux.ecsv', format='ascii.ecsv')
    sed_day4 = Table.read('../data/RSOph/RSOph_day4_diff_flux.ecsv', format='ascii.ecsv')

    # Group the SED data by day
    daily_data = [sed_day1, sed_day2, sed_day3, sed_day4]

    # Set initial parameters and labels for the model
    p0 = np.array((31, 2.5, np.log10(200)))  # Initial guesses for model parameters
    labels = ["log10(norm)", "index", "log10(cutoff)"]  # Labels for the parameters
    day_array = [1, 2, 3, 4]  # Days after the nova explosion

    # Clean up previous results if they exist
    os.system("rm ../fit_results/RSOph/hadronic_model/fit_naima_results_all*")

    # Loop over the data for each day
    for yy, iday in enumerate(day_array):
        p0 = np.array((31, 2.5, np.log10(200)))  # Reset initial parameters for each day
        day_value = iday  # Set the day value

        print("day", day_value)

        # Create the model function with the appropriate day value
        PionDecay_func = PionDecayModel(iday)
        
        # Run the sampler to fit the model to the data
        sampler, pos = naima.run_sampler(
            data_table=daily_data[yy],  # Use the data for the current day
            p0=p0,  # Initial parameter guesses
            labels=labels,  # Parameter labels
            model=PionDecay_func.PionDecay,  # Model to fit
            prior=lnprior,  # Prior distribution for parameters
            nwalkers=32,  # Number of walkers for the MCMC sampler
            nburn=10,  # Number of burn-in steps
            nrun=40,  # Number of steps to run the sampler
            threads=4,  # Number of threads to use
            prefit=True,  # Whether to perform a prefit
            interactive=False,  # Whether to allow interactive plotting
        )

        # Save the results of the fitting process
        out_root = "../fit_results/RSOph/hadronic_model/fit_naima_results_all_day{}".format(day_array[yy])
        naima.save_run(out_root + ".hdf5", sampler)  # Save the sampler output in HDF5 format

        # Save diagnostic plots and the results table
        naima.save_diagnostic_plots(out_root, sampler, sed=True)
        naima.save_results_table(out_root, sampler) 

        print( )
        print( )
# Out:
# Overwriting ../fit_results/RSOph/hadronic_model/RSOph_hadronic.py

# %% [markdown]
# Execute the script.

# %%
subprocess.run(["python","../fit_results/RSOph/hadronic_model/RSOph_hadronic.py"])
# Out:
# day 1
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [31.00620822  2.5         2.30103   ] [naima.core]
# INFO:    Initial lnprob(p0): -456.032 [naima.core]
# INFO:    New ML parameters : [30.5511529   2.48024554  2.43099639] [naima.core]
# INFO:    Maximum lnprob(p0): -8.249 [naima.core]
# Burning in the 32 walkers with 10 steps...
#
# Progress of the run: 0 percent (0 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :      0.125           0.01           0.0115
#   Last ensemble lnprob :  avg: -25.017, max: -8.274
#
# Progress of the run: 10 percent (1 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :      0.115          0.00958         0.0113
#   Last ensemble lnprob :  avg: -21.188, max: -8.326
#
# Progress of the run: 20 percent (2 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :      0.099          0.0084          0.0135
#   Last ensemble lnprob :  avg: -18.293, max: -8.297
#
# Progress of the run: 30 percent (3 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :     0.0835          0.0119          0.0134
#   Last ensemble lnprob :  avg: -16.228, max: -8.297
#
# Progress of the run: 40 percent (4 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :     0.0787           0.012          0.0152
#   Last ensemble lnprob :  avg: -15.108, max: -8.297
#
# Progress of the run: 50 percent (5 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :     0.0729          0.0119           0.015
#   Last ensemble lnprob :  avg: -14.096, max: -8.269
#
# Progress of the run: 60 percent (6 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :     0.0667          0.0126          0.0177
#   Last ensemble lnprob :  avg: -12.886, max: -8.269
#
# Progress of the run: 70 percent (7 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :     0.0649           0.013          0.0256
#   Last ensemble lnprob :  avg: -12.362, max: -8.269
#
# Progress of the run: 80 percent (8 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :     0.0622          0.0143          0.0232
#   Last ensemble lnprob :  avg: -11.876, max: -8.269
#
# Progress of the run: 90 percent (9 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :      0.059          0.0144          0.0234
#   Last ensemble lnprob :  avg: -11.345, max: -8.269
#
# Walker burn in finished, running 40 steps...
#
# Progress of the run: 0 percent (0 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.48            2.44
#   Last ensemble std    :     0.0592          0.0133          0.0305
#   Last ensemble lnprob :  avg: -11.497, max: -8.294
#
# Progress of the run: 5 percent (2 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.48            2.44
#   Last ensemble std    :     0.0523          0.0151          0.0305
#   Last ensemble lnprob :  avg: -10.976, max: -8.317
#
# Progress of the run: 10 percent (4 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.45
#   Last ensemble std    :     0.0458          0.0194          0.0372
#   Last ensemble lnprob :  avg: -10.180, max: -8.297
#
# Progress of the run: 15 percent (6 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.44
#   Last ensemble std    :      0.046          0.0247          0.0334
#   Last ensemble lnprob :  avg: -9.810, max: -8.306
#
# Progress of the run: 20 percent (8 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.49            2.44
#   Last ensemble std    :     0.0546          0.0382          0.0489
#   Last ensemble lnprob :  avg: -9.790, max: -8.327
#
# Progress of the run: 25 percent (10 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.49            2.44
#   Last ensemble std    :     0.0667          0.0483          0.0594
#   Last ensemble lnprob :  avg: -9.515, max: -8.331
#
# Progress of the run: 30 percent (12 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.49            2.43
#   Last ensemble std    :     0.0722          0.0535          0.0635
#   Last ensemble lnprob :  avg: -9.641, max: -8.262
#
# Progress of the run: 35 percent (14 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.49            2.44
#   Last ensemble std    :     0.0918          0.0703          0.0797
#   Last ensemble lnprob :  avg: -9.440, max: -8.333
#
# Progress of the run: 40 percent (16 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.49            2.44
#   Last ensemble std    :     0.0899          0.0713          0.0781
#   Last ensemble lnprob :  avg: -9.319, max: -8.273
#
# Progress of the run: 45 percent (18 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.42
#   Last ensemble std    :     0.0888          0.0754          0.0796
#   Last ensemble lnprob :  avg: -9.709, max: -8.345
#
# Progress of the run: 50 percent (20 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.47            2.43
#   Last ensemble std    :     0.0666          0.0636          0.0605
#   Last ensemble lnprob :  avg: -9.517, max: -8.274
#
# Progress of the run: 55 percent (22 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.47            2.42
#   Last ensemble std    :      0.067          0.0566          0.0637
#   Last ensemble lnprob :  avg: -9.545, max: -8.274
#
# Progress of the run: 60 percent (24 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.48            2.43
#   Last ensemble std    :     0.0731          0.0669          0.0682
#   Last ensemble lnprob :  avg: -9.575, max: -8.370
#
# Progress of the run: 65 percent (26 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.48            2.42
#   Last ensemble std    :      0.11           0.0937          0.0918
#   Last ensemble lnprob :  avg: -9.653, max: -8.285
#
# Progress of the run: 70 percent (28 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.48            2.42
#   Last ensemble std    :      0.11           0.0942          0.0965
#   Last ensemble lnprob :  avg: -9.561, max: -8.267
#
# Progress of the run: 75 percent (30 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.6            2.47            2.41
#   Last ensemble std    :      0.114          0.0906          0.0953
#   Last ensemble lnprob :  avg: -9.478, max: -8.267
#
# Progress of the run: 80 percent (32 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.49            2.44
#   Last ensemble std    :      0.104          0.0839          0.0884
#   Last ensemble lnprob :  avg: -9.628, max: -8.258
#
# Progress of the run: 85 percent (34 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.49            2.42
#   Last ensemble std    :      0.13           0.0999           0.109
#   Last ensemble lnprob :  avg: -9.693, max: -8.252
#
# Progress of the run: 90 percent (36 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.49            2.43
#   Last ensemble std    :      0.122          0.0966           0.104
#   Last ensemble lnprob :  avg: -9.637, max: -8.252
#
# Progress of the run: 95 percent (38 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      30.5            2.48            2.42
#   Last ensemble std    :      0.118          0.0915           0.102
#   Last ensemble lnprob :  avg: -9.736, max: -8.388
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $30.55 \pm 0.06$
#                  norm = $(3.5 \pm 0.5)\times10^{30}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $2.48 \pm 0.04$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $2.43^{+0.05}_{-0.07}$
#                  cutoff = $270 \pm 40$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Model output 0... [naima.analysis]
# /Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/site-packages/naima/analysis.py:153: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Model output 1: cannot convert float NaN to integer [naima.analysis]
# INFO: Plotting Model output 1... [naima.analysis]
# INFO: Saving results table in ../fit_results/RSOph/hadronic_model/fit_naima_results_all_day1_results.ecsv [naima.analysis]
#
#
# day 2
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [31.84083014  2.5         2.30103   ] [naima.core]
# INFO:    Initial lnprob(p0): -383.184 [naima.core]
# INFO:    New ML parameters : [31.08574968  2.67210129  2.92234262] [naima.core]
# INFO:    Maximum lnprob(p0): -11.265 [naima.core]
# Burning in the 32 walkers with 10 steps...
#
# Progress of the run: 0 percent (0 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :      0.132          0.0175          0.0168
#   Last ensemble lnprob :  avg: -25.122, max: -11.294
#
# Progress of the run: 10 percent (1 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :      0.127          0.0161           0.017
#   Last ensemble lnprob :  avg: -23.331, max: -11.296
#
# Progress of the run: 20 percent (2 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :      0.124          0.0169          0.0176
#   Last ensemble lnprob :  avg: -22.814, max: -11.289
#
# Progress of the run: 30 percent (3 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :      0.115          0.0163          0.0183
#   Last ensemble lnprob :  avg: -20.138, max: -11.274
#
# Progress of the run: 40 percent (4 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :      0.105          0.0167          0.0179
#   Last ensemble lnprob :  avg: -18.825, max: -11.267
#
# Progress of the run: 50 percent (5 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0984          0.0169          0.0197
#   Last ensemble lnprob :  avg: -17.622, max: -11.288
#
# Progress of the run: 60 percent (6 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :      0.093           0.018          0.0213
#   Last ensemble lnprob :  avg: -16.952, max: -11.288
#
# Progress of the run: 70 percent (7 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0642          0.0215          0.0255
#   Last ensemble lnprob :  avg: -14.220, max: -11.288
#
# Progress of the run: 80 percent (8 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0612          0.0212          0.0283
#   Last ensemble lnprob :  avg: -13.906, max: -11.286
#
# Progress of the run: 90 percent (9 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0535          0.0207          0.0285
#   Last ensemble lnprob :  avg: -13.539, max: -11.286
#
# Walker burn in finished, running 40 steps...
#
# Progress of the run: 0 percent (0 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0508          0.0176          0.0302
#   Last ensemble lnprob :  avg: -13.463, max: -11.293
#
# Progress of the run: 5 percent (2 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0482          0.0234          0.0347
#   Last ensemble lnprob :  avg: -13.239, max: -11.274
#
# Progress of the run: 10 percent (4 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0396          0.0235          0.0388
#   Last ensemble lnprob :  avg: -12.799, max: -11.274
#
# Progress of the run: 15 percent (6 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0528          0.0358          0.0724
#   Last ensemble lnprob :  avg: -12.807, max: -11.274
#
# Progress of the run: 20 percent (8 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.67            2.92
#   Last ensemble std    :     0.0529           0.032          0.0601
#   Last ensemble lnprob :  avg: -12.877, max: -11.302
#
# Progress of the run: 25 percent (10 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66             2.9
#   Last ensemble std    :      0.052          0.0312          0.0606
#   Last ensemble lnprob :  avg: -12.691, max: -11.308
#
# Progress of the run: 30 percent (12 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66             2.9
#   Last ensemble std    :     0.0709          0.0445          0.0806
#   Last ensemble lnprob :  avg: -12.684, max: -11.305
#
# Progress of the run: 35 percent (14 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66            2.89
#   Last ensemble std    :     0.0727           0.046          0.0841
#   Last ensemble lnprob :  avg: -12.660, max: -11.301
#
# Progress of the run: 40 percent (16 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66            2.89
#   Last ensemble std    :     0.0825           0.055          0.0993
#   Last ensemble lnprob :  avg: -13.095, max: -11.340
#
# Progress of the run: 45 percent (18 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66            2.88
#   Last ensemble std    :     0.0769          0.0557          0.0884
#   Last ensemble lnprob :  avg: -12.960, max: -11.341
#
# Progress of the run: 50 percent (20 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66            2.89
#   Last ensemble std    :     0.0797           0.057          0.0908
#   Last ensemble lnprob :  avg: -12.817, max: -11.323
#
# Progress of the run: 55 percent (22 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66            2.88
#   Last ensemble std    :     0.0777          0.0584          0.0916
#   Last ensemble lnprob :  avg: -12.714, max: -11.260
#
# Progress of the run: 60 percent (24 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.65            2.88
#   Last ensemble std    :     0.0794          0.0634          0.0981
#   Last ensemble lnprob :  avg: -12.777, max: -11.260
#
# Progress of the run: 65 percent (26 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.65            2.89
#   Last ensemble std    :     0.0726          0.0639          0.0983
#   Last ensemble lnprob :  avg: -12.577, max: -11.281
#
# Progress of the run: 70 percent (28 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66            2.88
#   Last ensemble std    :     0.0723          0.0642          0.0956
#   Last ensemble lnprob :  avg: -12.550, max: -11.350
#
# Progress of the run: 75 percent (30 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.65            2.89
#   Last ensemble std    :      0.078          0.0635            0.1
#   Last ensemble lnprob :  avg: -12.805, max: -11.273
#
# Progress of the run: 80 percent (32 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.66             2.9
#   Last ensemble std    :     0.0699          0.0589          0.0938
#   Last ensemble lnprob :  avg: -12.596, max: -11.281
#
# Progress of the run: 85 percent (34 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.65            2.88
#   Last ensemble std    :     0.0703          0.0582          0.0992
#   Last ensemble lnprob :  avg: -12.567, max: -11.281
#
# Progress of the run: 90 percent (36 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.64            2.87
#   Last ensemble std    :     0.0734          0.0621           0.104
#   Last ensemble lnprob :  avg: -12.765, max: -11.288
#
# Progress of the run: 95 percent (38 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.1            2.65            2.87
#   Last ensemble std    :     0.0664          0.0586          0.0966
#   Last ensemble lnprob :  avg: -12.811, max: -11.306
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $31.10^{+0.07}_{-0.05}$
#                  norm = $(1.25^{+0.2}_{-0.14})\times10^{31}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $2.66^{+0.03}_{-0.06}$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $2.90^{+0.05}_{-0.09}$
#                  cutoff = $790^{+100}_{-150}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Model output 0... [naima.analysis]
# /Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/site-packages/naima/analysis.py:153: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Model output 1: cannot convert float NaN to integer [naima.analysis]
# INFO: Plotting Model output 1... [naima.analysis]
# INFO: Saving results table in ../fit_results/RSOph/hadronic_model/fit_naima_results_all_day2_results.ecsv [naima.analysis]
#
#
# day 3
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [32.49634292  2.5         2.30103   ] [naima.core]
# INFO:    Initial lnprob(p0): -1221.275 [naima.core]
# INFO:    New ML parameters : [31.38817857  2.74059121  3.41215115] [naima.core]
# INFO:    Maximum lnprob(p0): -11.672 [naima.core]
# Burning in the 32 walkers with 10 steps...
#
# Progress of the run: 0 percent (0 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.3            2.74            3.42
#   Last ensemble std    :      0.138          0.0154          0.0136
#   Last ensemble lnprob :  avg: -25.274, max: -11.848
#
# Progress of the run: 10 percent (1 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.3            2.74            3.41
#   Last ensemble std    :      0.124          0.0145          0.0131
#   Last ensemble lnprob :  avg: -21.854, max: -11.848
#
# Progress of the run: 20 percent (2 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.42
#   Last ensemble std    :      0.111          0.0154          0.0145
#   Last ensemble lnprob :  avg: -20.488, max: -11.848
#
# Progress of the run: 30 percent (3 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :      0.101          0.0158          0.0158
#   Last ensemble lnprob :  avg: -18.868, max: -11.704
#
# Progress of the run: 40 percent (4 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :     0.0792          0.0135          0.0168
#   Last ensemble lnprob :  avg: -16.256, max: -11.718
#
# Progress of the run: 50 percent (5 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :      0.063          0.0135          0.0175
#   Last ensemble lnprob :  avg: -15.142, max: -11.718
#
# Progress of the run: 60 percent (6 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.42
#   Last ensemble std    :     0.0588          0.0168          0.0233
#   Last ensemble lnprob :  avg: -14.866, max: -11.718
#
# Progress of the run: 70 percent (7 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :     0.0491          0.0168          0.0272
#   Last ensemble lnprob :  avg: -14.133, max: -11.692
#
# Progress of the run: 80 percent (8 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :     0.0446          0.0178           0.028
#   Last ensemble lnprob :  avg: -13.872, max: -11.692
#
# Progress of the run: 90 percent (9 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :     0.0449          0.0225          0.0425
#   Last ensemble lnprob :  avg: -13.819, max: -11.729
#
# Walker burn in finished, running 40 steps...
#
# Progress of the run: 0 percent (0 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :     0.0445          0.0227          0.0385
#   Last ensemble lnprob :  avg: -13.758, max: -11.825
#
# Progress of the run: 5 percent (2 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74             3.4
#   Last ensemble std    :     0.0428          0.0261          0.0474
#   Last ensemble lnprob :  avg: -13.560, max: -11.702
#
# Progress of the run: 10 percent (4 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :     0.0383          0.0283          0.0493
#   Last ensemble lnprob :  avg: -13.530, max: -11.705
#
# Progress of the run: 15 percent (6 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.42
#   Last ensemble std    :     0.0433          0.0352          0.0677
#   Last ensemble lnprob :  avg: -13.792, max: -11.787
#
# Progress of the run: 20 percent (8 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74             3.4
#   Last ensemble std    :     0.0501          0.0407          0.0832
#   Last ensemble lnprob :  avg: -14.122, max: -11.679
#
# Progress of the run: 25 percent (10 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.75            3.42
#   Last ensemble std    :     0.0447          0.0374          0.0825
#   Last ensemble lnprob :  avg: -13.650, max: -11.679
#
# Progress of the run: 30 percent (12 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.75            3.41
#   Last ensemble std    :     0.0406          0.0344          0.0832
#   Last ensemble lnprob :  avg: -13.510, max: -11.775
#
# Progress of the run: 35 percent (14 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.41
#   Last ensemble std    :     0.0469          0.0372           0.101
#   Last ensemble lnprob :  avg: -13.472, max: -11.693
#
# Progress of the run: 40 percent (16 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74             3.4
#   Last ensemble std    :     0.0403          0.0326          0.0842
#   Last ensemble lnprob :  avg: -13.237, max: -11.693
#
# Progress of the run: 45 percent (18 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.75            3.39
#   Last ensemble std    :     0.0441          0.0368          0.0882
#   Last ensemble lnprob :  avg: -13.199, max: -11.742
#
# Progress of the run: 50 percent (20 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.38
#   Last ensemble std    :     0.0424          0.0366          0.0846
#   Last ensemble lnprob :  avg: -13.189, max: -11.883
#
# Progress of the run: 55 percent (22 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.73            3.37
#   Last ensemble std    :     0.0434          0.0406          0.0945
#   Last ensemble lnprob :  avg: -13.207, max: -11.786
#
# Progress of the run: 60 percent (24 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.73            3.36
#   Last ensemble std    :     0.0404          0.0381          0.0998
#   Last ensemble lnprob :  avg: -12.963, max: -11.711
#
# Progress of the run: 65 percent (26 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.73            3.35
#   Last ensemble std    :     0.0473           0.042           0.106
#   Last ensemble lnprob :  avg: -13.214, max: -11.753
#
# Progress of the run: 70 percent (28 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.73            3.35
#   Last ensemble std    :     0.0435          0.0375          0.0965
#   Last ensemble lnprob :  avg: -13.099, max: -11.840
#
# Progress of the run: 75 percent (30 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.74            3.34
#   Last ensemble std    :     0.0436          0.0357          0.0936
#   Last ensemble lnprob :  avg: -13.018, max: -11.729
#
# Progress of the run: 80 percent (32 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.73            3.35
#   Last ensemble std    :      0.048          0.0368           0.106
#   Last ensemble lnprob :  avg: -13.076, max: -11.729
#
# Progress of the run: 85 percent (34 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.73            3.34
#   Last ensemble std    :     0.0496          0.0429           0.125
#   Last ensemble lnprob :  avg: -13.102, max: -11.757
#
# Progress of the run: 90 percent (36 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.73            3.34
#   Last ensemble std    :     0.0629          0.0422           0.137
#   Last ensemble lnprob :  avg: -13.307, max: -11.720
#
# Progress of the run: 95 percent (38 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.4            2.73            3.31
#   Last ensemble std    :     0.0664          0.0515           0.153
#   Last ensemble lnprob :  avg: -13.480, max: -11.812
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $31.38 \pm 0.05$
#                  norm = $(2.4 \pm 0.3)\times10^{31}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $2.74 \pm 0.04$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $3.38 \pm 0.08$
#                  cutoff = $(2.4 \pm 0.5)\times10^{3}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Model output 0... [naima.analysis]
# /Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/site-packages/naima/analysis.py:153: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Model output 1: cannot convert float NaN to integer [naima.analysis]
# INFO: Plotting Model output 1... [naima.analysis]
# INFO: Saving results table in ../fit_results/RSOph/hadronic_model/fit_naima_results_all_day3_results.ecsv [naima.analysis]
#
#
# day 4
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [32.60606247  2.5         2.30103   ] [naima.core]
# INFO:    Initial lnprob(p0): -410.246 [naima.core]
# INFO:    New ML parameters : [31.69687348  2.66990214  3.30657869] [naima.core]
# INFO:    Maximum lnprob(p0): -13.252 [naima.core]
# Burning in the 32 walkers with 10 steps...
#
# Progress of the run: 0 percent (0 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67            3.31
#   Last ensemble std    :      0.103          0.0131           0.018
#   Last ensemble lnprob :  avg: -18.883, max: -13.262
#
# Progress of the run: 10 percent (1 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :      0.101          0.0143          0.0206
#   Last ensemble lnprob :  avg: -18.513, max: -13.271
#
# Progress of the run: 20 percent (2 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0824          0.0146          0.0176
#   Last ensemble lnprob :  avg: -17.210, max: -13.315
#
# Progress of the run: 30 percent (3 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0798          0.0151          0.0223
#   Last ensemble lnprob :  avg: -16.951, max: -13.250
#
# Progress of the run: 40 percent (4 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0752          0.0205          0.0257
#   Last ensemble lnprob :  avg: -16.530, max: -13.287
#
# Progress of the run: 50 percent (5 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0651          0.0181          0.0227
#   Last ensemble lnprob :  avg: -15.484, max: -13.248
#
# Progress of the run: 60 percent (6 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0632          0.0194          0.0226
#   Last ensemble lnprob :  avg: -15.383, max: -13.263
#
# Progress of the run: 70 percent (7 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0596          0.0199          0.0224
#   Last ensemble lnprob :  avg: -15.141, max: -13.254
#
# Progress of the run: 80 percent (8 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0574           0.017          0.0217
#   Last ensemble lnprob :  avg: -14.903, max: -13.278
#
# Progress of the run: 90 percent (9 of 10 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0518          0.0178          0.0258
#   Last ensemble lnprob :  avg: -14.846, max: -13.290
#
# Walker burn in finished, running 40 steps...
#
# Progress of the run: 0 percent (0 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0501          0.0187          0.0315
#   Last ensemble lnprob :  avg: -14.744, max: -13.259
#
# Progress of the run: 5 percent (2 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.32
#   Last ensemble std    :     0.0457          0.0261          0.0418
#   Last ensemble lnprob :  avg: -14.710, max: -13.288
#
# Progress of the run: 10 percent (4 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.32
#   Last ensemble std    :     0.0467           0.03           0.0472
#   Last ensemble lnprob :  avg: -14.847, max: -13.295
#
# Progress of the run: 15 percent (6 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0457          0.0296          0.0565
#   Last ensemble lnprob :  avg: -14.618, max: -13.254
#
# Progress of the run: 20 percent (8 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67             3.3
#   Last ensemble std    :     0.0554          0.0337          0.0698
#   Last ensemble lnprob :  avg: -14.695, max: -13.295
#
# Progress of the run: 25 percent (10 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67             3.3
#   Last ensemble std    :     0.0478          0.0319          0.0746
#   Last ensemble lnprob :  avg: -14.454, max: -13.257
#
# Progress of the run: 30 percent (12 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67             3.3
#   Last ensemble std    :     0.0566          0.0395          0.0928
#   Last ensemble lnprob :  avg: -14.702, max: -13.322
#
# Progress of the run: 35 percent (14 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67            3.29
#   Last ensemble std    :     0.0547          0.0336           0.106
#   Last ensemble lnprob :  avg: -14.432, max: -13.374
#
# Progress of the run: 40 percent (16 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67            3.28
#   Last ensemble std    :     0.0588          0.0286           0.122
#   Last ensemble lnprob :  avg: -14.303, max: -13.299
#
# Progress of the run: 45 percent (18 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67             3.3
#   Last ensemble std    :     0.0581          0.0382           0.133
#   Last ensemble lnprob :  avg: -14.270, max: -13.275
#
# Progress of the run: 50 percent (20 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67            3.31
#   Last ensemble std    :     0.0633          0.0485           0.145
#   Last ensemble lnprob :  avg: -14.689, max: -13.288
#
# Progress of the run: 55 percent (22 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66             3.3
#   Last ensemble std    :     0.0583          0.0335           0.114
#   Last ensemble lnprob :  avg: -14.424, max: -13.310
#
# Progress of the run: 60 percent (24 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66             3.3
#   Last ensemble std    :      0.06           0.0361           0.124
#   Last ensemble lnprob :  avg: -14.630, max: -13.297
#
# Progress of the run: 65 percent (26 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67            3.32
#   Last ensemble std    :     0.0624          0.0401           0.135
#   Last ensemble lnprob :  avg: -14.656, max: -13.312
#
# Progress of the run: 70 percent (28 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.67            3.28
#   Last ensemble std    :     0.0597          0.0424           0.14
#   Last ensemble lnprob :  avg: -14.482, max: -13.295
#
# Progress of the run: 75 percent (30 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.27
#   Last ensemble std    :     0.0639          0.0451           0.148
#   Last ensemble lnprob :  avg: -14.422, max: -13.268
#
# Progress of the run: 80 percent (32 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.65            3.29
#   Last ensemble std    :     0.0733          0.0439           0.165
#   Last ensemble lnprob :  avg: -14.689, max: -13.308
#
# Progress of the run: 85 percent (34 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.31
#   Last ensemble std    :     0.0809          0.0509           0.196
#   Last ensemble lnprob :  avg: -14.854, max: -13.450
#
# Progress of the run: 90 percent (36 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.33
#   Last ensemble std    :     0.0755          0.0483           0.181
#   Last ensemble lnprob :  avg: -14.734, max: -13.336
#
# Progress of the run: 95 percent (38 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      31.7            2.66            3.32
#   Last ensemble std    :     0.0879          0.0622           0.203
#   Last ensemble lnprob :  avg: -14.891, max: -13.424
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $31.69^{+0.05}_{-0.07}$
#                  norm = $(4.9 \pm 0.7)\times10^{31}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $2.66 \pm 0.04$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $3.30 \pm 0.10$
#                  cutoff = $(2.0^{+0.6}_{-0.4})\times10^{3}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Model output 0... [naima.analysis]
# /Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/site-packages/naima/analysis.py:153: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Model output 1: cannot convert float NaN to integer [naima.analysis]
# Exception ignored in: <function Pool.__del__ at 0x173fff2e0>
# Traceback (most recent call last):
#   File "/Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/multiprocessing/pool.py", line 271, in __del__
#   File "/Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/multiprocessing/queues.py", line 371, in put
# AttributeError: 'NoneType' object has no attribute 'dumps'
# INFO: Plotting Model output 1... [naima.analysis]
# INFO: Saving results table in ../fit_results/RSOph/hadronic_model/fit_naima_results_all_day4_results.ecsv [naima.analysis]
# CompletedProcess(args=['python', '../fit_results/RSOph/hadronic_model/RSOph_hadronic.py'], returncode=0)

# %% [markdown]
# ## Check the results

# %% [markdown]
# The script has finished. Let's check the results...

# %%
# Load results
tabs_hadronic = []
for day in days:
    tab = Table.read(f"../fit_results/RSOph/hadronic_model/fit_naima_results_all_day{day}_results.ecsv")
    tabs_hadronic.append(tab)

# %% [markdown]
# Display the table with the best-fit parameter values

# %%
display(tabs_hadronic[0])
# Out:
# <Table length=6>
#     label             median               unc_lo                unc_hi
#     str13            float64              float64               float64
# ------------- --------------------- -------------------- ---------------------
#   log10(norm)    30.546206443333656  0.06313498034229426   0.05635067508971048
#          norm 3.517275956845711e+30 4.75890508700829e+29 4.873060461017847e+29
#         index     2.482434487832061   0.0447980649088362   0.04267230164848934
# log10(cutoff)    2.4318201914746402    0.072118262269393     0.049298104604659
#        cutoff     270.2839091007358   41.354142527449795     32.48989406229197
#         blob1                   nan                  nan                   nan

# %%
# You can also load the hdf5 files
runs_hardonic = []
for day in days:
    file = f"../fit_results/RSOph/hadronic_model/fit_naima_results_all_day{day}.hdf5"
    run = naima.read_run(file, modelfn=None)
    runs_hardonic.append(run)
# naima.plot_corner(runs_hardonic[0]);
# naima.plot_chain(runs_hardonic[0], 0);

# %% [markdown]
# ### Diagnostic plots

# %% [markdown]
# #### Check the posterior distribution of a given parameter

# %%
Image("../fit_results/RSOph/hadronic_model/fit_naima_results_all_day1_chain_cutoff.png")

# %% [markdown]
# It shows the parameter value with respect to the step number of the chain, which can be used to assess the stability of the chain (blue traces highlight 5% of the walkers), a plot of the posterior distribution, and several statistics of the posterior distribution. One of these is the median and 16th and 84th percentiles of the distribution, which can be reported as the inferred marginalised value of the parameter and associated 1sigma uncertainty.

# %% [markdown]
# #### Check the corner plot

# %%
Image("../fit_results/RSOph/hadronic_model/fit_naima_results_all_day1_corner.png")

# %% [markdown]
# The relationship between the samples of the different parameters can be seen through a corner plot. The maximum likelihood parameter vector can be indicated with a cross.
#
# - Do the dependencies between the different parameters make sense? Are they correlated?

# %% [markdown]
# #### Check the model output

# %%
Image("../fit_results/RSOph/hadronic_model/fit_naima_results_all_day1_model0.png")

# %% [markdown]
# Here we see the representation of the results of the MCMC fitting on the SED. It shows the Maximum Likelihood model with a black line and 100 samples from the posterior distribution in grey.

# %% [markdown]
# However, these are diagnostic plots. They are not usually used in papers they are for diagnostics.
#
# Now we want to produce the latest plot: display the best-fit model with the SED data.
#
# Firstly, we have to use the best-fit particle energy distribution. Secondly, create the radiative model.

# %%
#Day 1
# Create the particle energy distribution using the best-fit values
particle_distribution_day1 = naima.models.ExponentialCutoffPowerLaw(
    tabs_hadronic[0]["median"][1]*u.Unit('1/eV'), 
    130.0 * u.GeV, 
    tabs_hadronic[0]["median"][2], 
    tabs_hadronic[0]["median"][4]*u.GeV
)
# Create the radiative model
radiative_model_day1 = naima.models.PionDecay(
    particle_distribution_day1, nh=6.0e8*(1/3)**(-3) * u.cm ** -3
)

#Day 2
particle_distribution_day2 = naima.models.ExponentialCutoffPowerLaw(
    tabs_hadronic[1]["median"][1]*u.Unit('1/eV'), 
    130.0 * u.GeV, 
    tabs_hadronic[1]["median"][2], 
    tabs_hadronic[1]["median"][4]*u.GeV
)
radiative_model_day2 = naima.models.PionDecay(
    particle_distribution_day2, nh=6.0e8*(2/3)**(-3) * u.cm ** -3
)

#Day 3
particle_distribution_day3 = naima.models.ExponentialCutoffPowerLaw(
    tabs_hadronic[2]["median"][1]*u.Unit('1/eV'), 
    130.0 * u.GeV, 
    tabs_hadronic[2]["median"][2], 
    tabs_hadronic[2]["median"][4]*u.GeV
)
radiative_model_day3 = naima.models.PionDecay(
    particle_distribution_day3, nh=6.0e8*(3/3)**(-3) * u.cm ** -3
)

#Day 4
particle_distribution_day4 = naima.models.ExponentialCutoffPowerLaw(
    tabs_hadronic[3]["median"][1]*u.Unit('1/eV'), 
    130.0 * u.GeV, 
    tabs_hadronic[3]["median"][2], 
    tabs_hadronic[3]["median"][4]*u.GeV
)
radiative_model_day4 = naima.models.PionDecay(
    particle_distribution_day4, nh=6.0e8*(4/3)**(-3) * u.cm ** -3
)

# %% [markdown]
# We are ready to show the results

# %%
# import the class PionDecayModel from the file we created before
from fit_results.RSOph.hadronic_model.RSOph_hadronic import PionDecayModel

# Define photon energy range for plotting SED (Spectral Energy Distribution)
photon_energy = np.geomspace(6e-5, 2.6, 100) * u.TeV

# Use the quantity_support context manager to enable operations with quantities
with quantity_support():
    # Loop through days, corresponding data, and radiative models
    for ii, (day, data, rad_model) in enumerate(
        zip(
            days,
            daily_data,
            [radiative_model_day1, radiative_model_day2, radiative_model_day3, radiative_model_day4]
        )
    ):
        # Create a plot of the data for each day using the 'naima' plotting function
        fig = naima.plot_data(data, e_unit=u.GeV)  # Plot data with energy unit as GeV
        ax = fig.axes[0]  # Get the plot axis
        ax.set_title(f"Day {day} after eruption")  # Set plot title with the day of observation

        # Set units for the x-axis and y-axis
        ax.xaxis.units = u.GeV  # Set the x-axis to be in GeV
        ax.yaxis.units = u.Unit("erg s-1 cm-2")  # Set the y-axis to have units of erg/s/cm^2

        # Store the current axis limits for both x and y
        ymin, ymax = ax.get_ylim()
        xmin, xmax = ax.get_xlim()

        # Plot the best-fit Inverse Compton (IC) SED
        plt.loglog(
            photon_energy,  # The photon energies to plot
            rad_model.sed(photon_energy, distance=2.45 * u.kpc),  # Calculate and plot the model flux (SED)
            color="k",  # Color of the line
            label=r"Best-fit ($pp \rightarrow \pi_0 \rightarrow \gamma\gamma$)"  # Label for the plot
        )

        # Create a PionDecay model for the current day
        PionDecay_func = PionDecayModel(day)

        # Loop through each MCMC chain sample and plot the corresponding flux
        for i in range(min(np.shape(runs_hardonic[ii].get_chain())[1], 100)):
            photon_energy = np.geomspace(xmin, xmax, 100) * u.GeV  # Define photon energy range for plotting
            # Get flux prediction from the PionDecay model for this sample in the MCMC chain
            flux = PionDecay_func.PionDecay(runs_hardonic[ii].get_chain()[-1, i, :], data=photon_energy)
            # SED := E**2 * differential flux (d\phi/dE), plot each flux sample in gray with some transparency
            plt.loglog(photon_energy, photon_energy**2 * flux, color="gray", alpha=0.1)

        # Restore the original y-axis limits to avoid distorting the plot
        ax.set_ylim((ymin, ymax))
        # Set axis labels for the plot
        ax.set_ylabel(f"E$^2$ d$\phi$/dE (erg cm$^{{-2}}$ s$^{{-1}}$)")  # y-axis label (flux)
        ax.set_xlabel(f"Energy (GeV)")  # x-axis label (energy)

        # Add a legend to the plot
        ax.legend()

# %% [markdown]
# #### Plot the maximum likelihood model parameter results

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize lists to store parameter values and uncertainties
tabs_val = []
tabs_err_lo = []
tabs_err_hi = []
labels = ["log10(norm)", "index", "cutoff"]

# Extract values and uncertainties for selected parameters
for tab in tabs_hadronic:
    tab_val, tab_err_lo, tab_err_hi = [], [], []    
    for i in range(len(tab)):
        if tab["label"][i] in labels:
            tab_val.append(tab["median"][i])
            tab_err_lo.append(tab["unc_lo"][i])
            tab_err_hi.append(tab["unc_hi"][i])
    tabs_val.append(tab_val)
    tabs_err_lo.append(tab_err_lo)
    tabs_err_hi.append(tab_err_hi)

# Convert lists to numpy arrays
tabs_val = np.array(tabs_val)
tabs_err_lo = np.array(tabs_err_lo)
tabs_err_hi = np.array(tabs_err_hi)

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(24, 6))

# Plot the log of the amplitude (norm)
axs[0].errorbar(
    x=days, y=tabs_val[:, 0], 
    yerr=[tabs_err_lo[:, 0], tabs_err_hi[:, 0]],
    ls=":", capsize=3, marker="o"
)
axs[0].set_ylabel(fr"{labels[0]} [eV$^{{-1}}$]")
axs[0].set_xlabel(r"T-T$_0$ (days)")

# Plot the power-law index
axs[1].errorbar(
    x=days, y=tabs_val[:, 1], 
    yerr=[tabs_err_lo[:, 1], tabs_err_hi[:, 1]], 
    ls=":", capsize=3, marker="o"
)
axs[1].set_ylabel(labels[1])
axs[1].set_xlabel(r"T-T$_0$ (days)")

# Plot the cutoff energy
axs[2].errorbar(
    x=days, y=tabs_val[:, 2] / 1000, # GeV -> TeV
    yerr=[(tabs_val[:, 2] - tabs_err_lo[:, 2]) / 1000, 
          (tabs_val[:, 2] + tabs_err_hi[:, 2]) / 1000], 
        ls=":", capsize=3, marker="o"
)
axs[2].set_yscale("log")
axs[2].set_ylabel(fr"E$_{{\rm cutoff}}$ (TeV)")
axs[2].set_xlabel(r"T-T$_0$ (days)");

# %% [markdown]
# #### Plot the proton energy distribution

# %%
# range of proton energies
Penergy=np.geomspace(1,1e5,100)*u.GeV

# plot the electron energy distribution for each day
for ii,particle_distribution in enumerate([
    particle_distribution_day1, 
    particle_distribution_day2, 
    particle_distribution_day3, 
    particle_distribution_day4
]):
    plt.loglog(
        Penergy,
        particle_distribution._calc(Penergy), # evaluate the model at that energy
        label=f"Day {ii+1}",
    )

# mark the reference energy of the model (i.e. the energy of the amplitude value)
plt.vlines(130,1e6,1e40,ls="--",color="gray",label="Reference point (e_0)")

plt.legend()
plt.ylim((1e6,1e40))
plt.xlabel("Energy (GeV)")
plt.ylabel(f"d$N_{{\\rm p}}$/d$E$ (protons eV$^{{-1}}$)");

# %% [markdown]
# # Leptonic model
#
# In this case, we use electrons to explain the gamma-ray emission. We will use the inverse Compton scattering.

# %%
# %%writefile ../fit_results/RSOph/leptonic_model/RSOph_leptonic.py

# Import necessary libraries
import astropy.units as u
import numpy as np
from astropy.io import ascii
from astropy.table import vstack
import naima
from naima.models import ExponentialCutoffPowerLaw, InverseCompton
import os
from astropy.table import Table

class ICmodel:
    """
    Define a model for the Inverse Compton (IC) emission from an electron distribution,
    following a power-law with exponential cut-off.
    
    The photon energy density is parameterized as a function of the day
    after the nova explosion. The characteristic photon temperature is
    also day-dependent.
    """
    def __init__(self, day_value):
        assert day_value in [1, 2, 3, 4]  # Ensure that the day_value is valid (1 to 4)
        self.day_value = day_value
        # Array of photon temperatures for each day after nova explosion
        Temp_value_array = [10780, 9500, 8460, 7680]
        # Select the temperature for the current day
        self.Temp_value = Temp_value_array[self.day_value - 1]

    def IC(self, pars, data):
        """
        Define particle distribution model, radiative model, and return 
        the flux at the provided energy values.

        Parameters
        ----------
        pars : list
            The model parameters: [amplitude, index, log10(cutoff)].
        data : Table
            Data table containing energy and flux values.

        Returns
        -------
        flux : Quantity
            The computed flux at the provided energy values.
        """
        # Extract parameters for the model: amplitude, index, and cutoff energy
        amplitude = 10**pars[0] / u.eV  # Convert amplitude to proper units (eV^-1)
        alpha = pars[1]  # Spectral index
        e_cutoff = (10 ** pars[2]) * u.GeV  # Exponential cutoff energy

        # Define the Exponential Cutoff Power Law particle distribution model
        ECPL = ExponentialCutoffPowerLaw(amplitude, 130 * u.GeV, alpha, e_cutoff)
        
        # Define the Inverse Compton radiative model using CMB and photosphere photon fields
        IC = InverseCompton(
            ECPL,
            seed_photon_fields=[
                "CMB",  # Cosmic Microwave Background
                ["photosphere", 
                 self.Temp_value * u.K,  # Temperature of the photosphere (dependent on day)
                 0.14 * ((self.Temp_value / 8460) ** 4 / (self.day_value / 3) ** 2) * u.Unit("erg cm-3")]
            ],
        )
        # Compute the flux based on the provided data and distance
        return IC.flux(data, distance=2.45 * u.kpc)


def lnprior(pars):
    """
    Define the prior distribution for the model parameters.
    The amplitude is constrained to be positive.

    Parameters
    ----------
    pars : list
        Model parameters.

    Returns
    -------
    logprob : float
        The logarithmic prior probability for the parameters.
    """
    # Limit amplitude to positive values using a uniform prior
    logprob = naima.uniform_prior(pars[0], 0, np.inf)
    return logprob

if __name__ == '__main__':

    # Set initial model parameters and labels for MCMC sampling
    labels = ["log10(norm)", "index", "log10(cutoff)"]
    day_array = [1, 2, 3, 4]  # Days for which data will be used

    # Read the SED data for each day
    sed_day1 = Table.read('../data/RSOph/RSOph_day1_diff_flux.ecsv', format='ascii.ecsv')
    sed_day2 = Table.read('../data/RSOph/RSOph_day2_diff_flux.ecsv', format='ascii.ecsv')
    sed_day3 = Table.read('../data/RSOph/RSOph_day3_diff_flux.ecsv', format='ascii.ecsv')
    sed_day4 = Table.read('../data/RSOph/RSOph_day4_diff_flux.ecsv', format='ascii.ecsv')

    # Group the daily data into a list for easy access
    daily_data = [sed_day1, sed_day2, sed_day3, sed_day4]

    # Remove any previous results to avoid overwriting issues
    os.system("rm ../fit_results/RSOph/leptonic_model/fit_naima_results_all*")

    # Loop through each day of data
    for yy, iday in enumerate(day_array):
        
        p0 = np.array((27, 2.5, np.log10(200)))  # Initial guess for model parameters
        day_value = iday  # Set the current day value
        IC_func = ICmodel(day_value)  # Create the IC model for the current day

        print("day", day_value)

        # Run the MCMC sampler to fit the model to the data
        sampler, pos = naima.run_sampler(
            data_table=daily_data[yy],  # The data for the current day
            p0=p0,  # Initial parameters
            labels=labels,  # Parameter labels
            model=IC_func.IC,  # The model to fit (IC emission)
            prior=lnprior,  # The prior distribution
            nwalkers=50,  # Number of walkers in the MCMC chain
            nburn=50,  # Number of burn-in steps
            nrun=40,  # Number of sampling steps
            prefit=True,  # Perform a prefitting step with the initial parameters
            interactive=True,  # Allow interactive adjustment of p0 (only in command line)
        )
        
        # Save the results of the sampling run to a file
        out_root = "../fit_results/RSOph/leptonic_model/fit_naima_results_all_day{}".format(day_array[yy])
        naima.save_run(out_root + ".hdf5", sampler)

        # Save diagnostic plots and results table
        naima.save_diagnostic_plots(out_root, sampler, sed=True)
        naima.save_results_table(out_root, sampler)

        print()
        print()
# Out:
# Overwriting ../fit_results/RSOph/leptonic_model/RSOph_leptonic.py

# %%
subprocess.run(["python","../fit_results/RSOph/leptonic_model/RSOph_leptonic.py"])
# Out:
# day 1
# INFO: Launching interactive model fitter, close when finished [naima.core]
# WARNING: "cl" keyword not provided in input data table, upper limits will be assumed to be at 90% confidence level [naima.utils]
# Figure(640x480)
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [28.35270949  2.5         2.30103   ] [naima.core]
# INFO:    Initial lnprob(p0): -13766.914 [naima.core]
# INFO:    New ML parameters : [27.40187204  2.9310723   2.0501191 ] [naima.core]
# INFO:    Maximum lnprob(p0): -21.255 [naima.core]
# Burning in the 50 walkers with 50 steps...
#
# Progress of the run: 0 percent (0 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.4            2.93            2.05
#   Last ensemble std    :      0.126          0.0123          0.00879
#   Last ensemble lnprob :  avg: -35.067, max: -21.183
#
# Progress of the run: 10 percent (5 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.4            2.93            2.05
#   Last ensemble std    :     0.0714          0.0182          0.0111
#   Last ensemble lnprob :  avg: -25.735, max: -21.231
#
# Progress of the run: 20 percent (10 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.4            2.93            2.05
#   Last ensemble std    :     0.0587          0.0275          0.0153
#   Last ensemble lnprob :  avg: -23.461, max: -21.238
#
# Progress of the run: 30 percent (15 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.4            2.93            2.05
#   Last ensemble std    :     0.0608          0.0372          0.0256
#   Last ensemble lnprob :  avg: -22.715, max: -21.149
#
# Progress of the run: 40 percent (20 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.4            2.93            2.04
#   Last ensemble std    :     0.0527          0.0402          0.0262
#   Last ensemble lnprob :  avg: -22.637, max: -20.972
#
# Progress of the run: 50 percent (25 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.4            2.92            2.04
#   Last ensemble std    :     0.0569          0.0418          0.0358
#   Last ensemble lnprob :  avg: -22.541, max: -20.378
#
# Progress of the run: 60 percent (30 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.4            2.91            2.03
#   Last ensemble std    :     0.0864           0.057          0.0582
#   Last ensemble lnprob :  avg: -22.688, max: -20.459
#
# Progress of the run: 70 percent (35 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.4             2.9            2.02
#   Last ensemble std    :      0.121          0.0741          0.0796
#   Last ensemble lnprob :  avg: -22.110, max: -19.697
#
# Progress of the run: 80 percent (40 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.5            2.89            1.99
#   Last ensemble std    :      0.161           0.103           0.11
#   Last ensemble lnprob :  avg: -21.759, max: -18.420
#
# Progress of the run: 90 percent (45 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.5            2.87            1.95
#   Last ensemble std    :      0.201           0.127           0.137
#   Last ensemble lnprob :  avg: -21.421, max: -18.651
#
# Walker burn in finished, running 40 steps...
#
# Progress of the run: 0 percent (0 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.6            2.82             1.9
#   Last ensemble std    :      0.218           0.141           0.14
#   Last ensemble lnprob :  avg: -20.758, max: -18.004
#
# Progress of the run: 5 percent (2 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.6             2.8            1.88
#   Last ensemble std    :      0.239           0.153           0.148
#   Last ensemble lnprob :  avg: -20.617, max: -17.950
#
# Progress of the run: 10 percent (4 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.7            2.78            1.86
#   Last ensemble std    :      0.256           0.162           0.155
#   Last ensemble lnprob :  avg: -20.316, max: -17.545
#
# Progress of the run: 15 percent (6 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.7            2.78            1.83
#   Last ensemble std    :      0.262           0.168           0.149
#   Last ensemble lnprob :  avg: -19.892, max: -17.304
#
# Progress of the run: 20 percent (8 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.7            2.75            1.83
#   Last ensemble std    :      0.295           0.187           0.165
#   Last ensemble lnprob :  avg: -20.037, max: -17.799
#
# Progress of the run: 25 percent (10 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.7            2.73            1.82
#   Last ensemble std    :      0.296           0.188           0.165
#   Last ensemble lnprob :  avg: -19.814, max: -17.410
#
# Progress of the run: 30 percent (12 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8             2.7            1.79
#   Last ensemble std    :      0.289           0.185           0.165
#   Last ensemble lnprob :  avg: -19.868, max: -17.408
#
# Progress of the run: 35 percent (14 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            2.69             1.8
#   Last ensemble std    :      0.282           0.181           0.16
#   Last ensemble lnprob :  avg: -19.814, max: -17.445
#
# Progress of the run: 40 percent (16 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            2.69            1.76
#   Last ensemble std    :      0.287           0.184           0.162
#   Last ensemble lnprob :  avg: -19.711, max: -17.432
#
# Progress of the run: 45 percent (18 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            2.68            1.76
#   Last ensemble std    :      0.262           0.168           0.144
#   Last ensemble lnprob :  avg: -19.665, max: -17.327
#
# Progress of the run: 50 percent (20 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.9            2.64            1.75
#   Last ensemble std    :      0.304           0.197           0.167
#   Last ensemble lnprob :  avg: -19.851, max: -17.419
#
# Progress of the run: 55 percent (22 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.9            2.61            1.74
#   Last ensemble std    :      0.294           0.189           0.16
#   Last ensemble lnprob :  avg: -19.540, max: -17.458
#
# Progress of the run: 60 percent (24 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.9            2.61            1.72
#   Last ensemble std    :      0.294           0.188           0.154
#   Last ensemble lnprob :  avg: -19.255, max: -17.321
#
# Progress of the run: 65 percent (26 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.9             2.6             1.7
#   Last ensemble std    :      0.298           0.19            0.159
#   Last ensemble lnprob :  avg: -19.274, max: -17.321
#
# Progress of the run: 70 percent (28 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :       28             2.56            1.67
#   Last ensemble std    :      0.327           0.205           0.174
#   Last ensemble lnprob :  avg: -19.465, max: -17.400
#
# Progress of the run: 75 percent (30 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :       28             2.56            1.67
#   Last ensemble std    :      0.291           0.183           0.155
#   Last ensemble lnprob :  avg: -19.197, max: -17.382
#
# Progress of the run: 80 percent (32 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :       28             2.55            1.66
#   Last ensemble std    :      0.284           0.18            0.146
#   Last ensemble lnprob :  avg: -19.084, max: -17.322
#
# Progress of the run: 85 percent (34 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :       28             2.53            1.66
#   Last ensemble std    :      0.306           0.19            0.159
#   Last ensemble lnprob :  avg: -19.359, max: -17.323
#
# Progress of the run: 90 percent (36 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            2.51            1.64
#   Last ensemble std    :      0.265           0.164           0.14
#   Last ensemble lnprob :  avg: -19.392, max: -17.405
#
# Progress of the run: 95 percent (38 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            2.51            1.63
#   Last ensemble std    :      0.254           0.156           0.132
#   Last ensemble lnprob :  avg: -19.124, max: -17.345
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $27.8 \pm 0.3$
#                  norm = $(7^{+8}_{-4})\times10^{27}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $2.7 \pm 0.2$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $1.75 \pm 0.18$
#                  cutoff = $56^{+30}_{-18}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Model output 0... [naima.analysis]
# /Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/site-packages/naima/analysis.py:153: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Model output 1: cannot convert float NaN to integer [naima.analysis]
# WARNING: "cl" keyword not provided in input data table, upper limits will be assumed to be at 90% confidence level [naima.utils]
# INFO: Plotting Model output 1... [naima.analysis]
# INFO: Saving results table in ../fit_results/RSOph/leptonic_model/fit_naima_results_all_day1_results.ecsv [naima.analysis]
#
#
# day 2
# INFO: Launching interactive model fitter, close when finished [naima.core]
# Figure(640x480)
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [29.08082583  2.5         2.30103   ] [naima.core]
# INFO:    Initial lnprob(p0): -13186.494 [naima.core]
# INFO:    New ML parameters : [27.82032112  3.14182655  2.54164798] [naima.core]
# INFO:    Maximum lnprob(p0): -17.208 [naima.core]
# Burning in the 50 walkers with 50 steps...
#
# Progress of the run: 0 percent (0 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.55
#   Last ensemble std    :      0.129          0.0135          0.0118
#   Last ensemble lnprob :  avg: -28.612, max: -17.242
#
# Progress of the run: 10 percent (5 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.55
#   Last ensemble std    :     0.0852          0.0159          0.0171
#   Last ensemble lnprob :  avg: -22.752, max: -17.207
#
# Progress of the run: 20 percent (10 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.54
#   Last ensemble std    :     0.0544          0.0205          0.0288
#   Last ensemble lnprob :  avg: -19.479, max: -17.249
#
# Progress of the run: 30 percent (15 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.55
#   Last ensemble std    :     0.0504          0.0293          0.0467
#   Last ensemble lnprob :  avg: -18.896, max: -17.202
#
# Progress of the run: 40 percent (20 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.54
#   Last ensemble std    :     0.0439          0.0331           0.061
#   Last ensemble lnprob :  avg: -18.376, max: -17.274
#
# Progress of the run: 50 percent (25 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.15            2.55
#   Last ensemble std    :     0.0574          0.0449           0.087
#   Last ensemble lnprob :  avg: -18.511, max: -17.252
#
# Progress of the run: 60 percent (30 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.53
#   Last ensemble std    :     0.0814          0.0583           0.114
#   Last ensemble lnprob :  avg: -18.696, max: -17.255
#
# Progress of the run: 70 percent (35 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.15            2.55
#   Last ensemble std    :      0.077          0.0504           0.118
#   Last ensemble lnprob :  avg: -18.496, max: -17.309
#
# Progress of the run: 80 percent (40 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.15            2.56
#   Last ensemble std    :      0.096          0.0654           0.144
#   Last ensemble lnprob :  avg: -18.683, max: -17.346
#
# Progress of the run: 90 percent (45 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.55
#   Last ensemble std    :     0.0975          0.0668           0.134
#   Last ensemble lnprob :  avg: -18.491, max: -17.248
#
# Walker burn in finished, running 40 steps...
#
# Progress of the run: 0 percent (0 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.54
#   Last ensemble std    :     0.0932          0.0619           0.124
#   Last ensemble lnprob :  avg: -18.505, max: -17.214
#
# Progress of the run: 5 percent (2 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.54
#   Last ensemble std    :     0.0895           0.057           0.126
#   Last ensemble lnprob :  avg: -18.559, max: -17.244
#
# Progress of the run: 10 percent (4 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.14            2.51
#   Last ensemble std    :     0.0899          0.0581           0.123
#   Last ensemble lnprob :  avg: -18.564, max: -17.296
#
# Progress of the run: 15 percent (6 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.13            2.51
#   Last ensemble std    :     0.0748          0.0508           0.112
#   Last ensemble lnprob :  avg: -18.557, max: -17.218
#
# Progress of the run: 20 percent (8 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.13            2.51
#   Last ensemble std    :      0.073          0.0507           0.108
#   Last ensemble lnprob :  avg: -18.628, max: -17.214
#
# Progress of the run: 25 percent (10 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.12            2.51
#   Last ensemble std    :     0.0626          0.0462          0.0981
#   Last ensemble lnprob :  avg: -18.413, max: -17.235
#
# Progress of the run: 30 percent (12 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.12            2.53
#   Last ensemble std    :     0.0685          0.0522           0.103
#   Last ensemble lnprob :  avg: -18.539, max: -17.232
#
# Progress of the run: 35 percent (14 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.12            2.53
#   Last ensemble std    :     0.0764           0.056           0.112
#   Last ensemble lnprob :  avg: -18.595, max: -17.247
#
# Progress of the run: 40 percent (16 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.12             2.5
#   Last ensemble std    :     0.0773          0.0588           0.124
#   Last ensemble lnprob :  avg: -18.685, max: -17.262
#
# Progress of the run: 45 percent (18 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.12            2.51
#   Last ensemble std    :     0.0837          0.0644           0.13
#   Last ensemble lnprob :  avg: -18.538, max: -17.243
#
# Progress of the run: 50 percent (20 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.9            3.12            2.49
#   Last ensemble std    :     0.0843          0.0613           0.128
#   Last ensemble lnprob :  avg: -18.694, max: -17.356
#
# Progress of the run: 55 percent (22 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.13            2.49
#   Last ensemble std    :     0.0886           0.065           0.134
#   Last ensemble lnprob :  avg: -18.723, max: -17.250
#
# Progress of the run: 60 percent (24 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.13            2.49
#   Last ensemble std    :     0.0713          0.0559           0.125
#   Last ensemble lnprob :  avg: -18.559, max: -17.381
#
# Progress of the run: 65 percent (26 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.13             2.5
#   Last ensemble std    :     0.0899           0.07            0.144
#   Last ensemble lnprob :  avg: -18.538, max: -17.256
#
# Progress of the run: 70 percent (28 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.12             2.5
#   Last ensemble std    :      0.105          0.0781           0.149
#   Last ensemble lnprob :  avg: -18.695, max: -17.242
#
# Progress of the run: 75 percent (30 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.11             2.5
#   Last ensemble std    :      0.101           0.077           0.144
#   Last ensemble lnprob :  avg: -18.821, max: -17.328
#
# Progress of the run: 80 percent (32 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.11            2.49
#   Last ensemble std    :      0.117           0.089           0.174
#   Last ensemble lnprob :  avg: -18.942, max: -17.214
#
# Progress of the run: 85 percent (34 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.9            3.11            2.49
#   Last ensemble std    :      0.103          0.0765           0.186
#   Last ensemble lnprob :  avg: -18.810, max: -17.259
#
# Progress of the run: 90 percent (36 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.11            2.49
#   Last ensemble std    :      0.11           0.0761           0.16
#   Last ensemble lnprob :  avg: -18.899, max: -17.358
#
# Progress of the run: 95 percent (38 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      27.8            3.11            2.51
#   Last ensemble std    :     0.0905          0.0607           0.132
#   Last ensemble lnprob :  avg: -18.696, max: -17.205
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $27.84 \pm 0.08$
#                  norm = $(6.9^{+1.4}_{-1.0})\times10^{27}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $3.12 \pm 0.06$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $2.51 \pm 0.13$
#                  cutoff = $320 \pm 90$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Model output 0... [naima.analysis]
# /Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/site-packages/naima/analysis.py:153: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Model output 1: cannot convert float NaN to integer [naima.analysis]
# WARNING: "cl" keyword not provided in input data table, upper limits will be assumed to be at 90% confidence level [naima.utils]
# INFO: Plotting Model output 1... [naima.analysis]
# INFO: Saving results table in ../fit_results/RSOph/leptonic_model/fit_naima_results_all_day2_results.ecsv [naima.analysis]
#
#
# day 3
# INFO: Launching interactive model fitter, close when finished [naima.core]
# Figure(640x480)
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [29.74026449  2.5         2.30103   ] [naima.core]
# INFO:    Initial lnprob(p0): -26693.945 [naima.core]
# INFO:    New ML parameters : [28.15434228  3.1733362   3.03653082] [naima.core]
# INFO:    Maximum lnprob(p0): -21.004 [naima.core]
# Burning in the 50 walkers with 50 steps...
#
# Progress of the run: 0 percent (0 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.17            3.04
#   Last ensemble std    :      0.115           0.015          0.0132
#   Last ensemble lnprob :  avg: -30.096, max: -21.048
#
# Progress of the run: 10 percent (5 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17            3.04
#   Last ensemble std    :      0.07           0.0166          0.0235
#   Last ensemble lnprob :  avg: -23.966, max: -21.032
#
# Progress of the run: 20 percent (10 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.18            3.04
#   Last ensemble std    :     0.0527          0.0296          0.0563
#   Last ensemble lnprob :  avg: -22.785, max: -21.000
#
# Progress of the run: 30 percent (15 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18            3.04
#   Last ensemble std    :     0.0523          0.0398          0.0893
#   Last ensemble lnprob :  avg: -22.486, max: -20.984
#
# Progress of the run: 40 percent (20 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.17            3.03
#   Last ensemble std    :     0.0484          0.0378           0.12
#   Last ensemble lnprob :  avg: -22.297, max: -21.071
#
# Progress of the run: 50 percent (25 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.16            3.02
#   Last ensemble std    :     0.0519          0.0412           0.152
#   Last ensemble lnprob :  avg: -22.172, max: -20.953
#
# Progress of the run: 60 percent (30 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.17            3.01
#   Last ensemble std    :     0.0519          0.0377           0.175
#   Last ensemble lnprob :  avg: -22.232, max: -20.961
#
# Progress of the run: 70 percent (35 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17            3.05
#   Last ensemble std    :     0.0636          0.0414           0.19
#   Last ensemble lnprob :  avg: -22.313, max: -20.990
#
# Progress of the run: 80 percent (40 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17            3.08
#   Last ensemble std    :     0.0676          0.0458           0.228
#   Last ensemble lnprob :  avg: -22.140, max: -20.963
#
# Progress of the run: 90 percent (45 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17            3.08
#   Last ensemble std    :     0.0685          0.0514           0.304
#   Last ensemble lnprob :  avg: -22.132, max: -21.070
#
# Walker burn in finished, running 40 steps...
#
# Progress of the run: 0 percent (0 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17              3
#   Last ensemble std    :     0.0691          0.0517           0.466
#   Last ensemble lnprob :  avg: -21.936, max: -20.968
#
# Progress of the run: 5 percent (2 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.17            3.01
#   Last ensemble std    :     0.0756          0.0543           0.476
#   Last ensemble lnprob :  avg: -21.978, max: -20.968
#
# Progress of the run: 10 percent (4 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.17            3.01
#   Last ensemble std    :     0.0817          0.0603           0.629
#   Last ensemble lnprob :  avg: -22.227, max: -20.949
#
# Progress of the run: 15 percent (6 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.17            3.07
#   Last ensemble std    :     0.0771          0.0561           0.513
#   Last ensemble lnprob :  avg: -22.062, max: -20.933
#
# Progress of the run: 20 percent (8 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.16            3.06
#   Last ensemble std    :     0.0892          0.0607           0.527
#   Last ensemble lnprob :  avg: -22.227, max: -20.931
#
# Progress of the run: 25 percent (10 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17             3.1
#   Last ensemble std    :     0.0888          0.0604           0.476
#   Last ensemble lnprob :  avg: -22.162, max: -21.105
#
# Progress of the run: 30 percent (12 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.17            3.08
#   Last ensemble std    :     0.0776          0.0571           0.553
#   Last ensemble lnprob :  avg: -22.050, max: -21.076
#
# Progress of the run: 35 percent (14 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17            3.06
#   Last ensemble std    :     0.0792           0.056           0.539
#   Last ensemble lnprob :  avg: -22.040, max: -21.010
#
# Progress of the run: 40 percent (16 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.2            3.17            3.07
#   Last ensemble std    :     0.0813          0.0571           0.649
#   Last ensemble lnprob :  avg: -22.160, max: -21.034
#
# Progress of the run: 45 percent (18 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17            3.06
#   Last ensemble std    :     0.0781          0.0529           0.67
#   Last ensemble lnprob :  avg: -22.279, max: -21.050
#
# Progress of the run: 50 percent (20 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18            3.05
#   Last ensemble std    :     0.0768          0.0531           0.516
#   Last ensemble lnprob :  avg: -22.310, max: -20.999
#
# Progress of the run: 55 percent (22 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17            3.04
#   Last ensemble std    :     0.0732          0.0525           0.587
#   Last ensemble lnprob :  avg: -22.454, max: -21.026
#
# Progress of the run: 60 percent (24 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.17            3.06
#   Last ensemble std    :     0.0741          0.0547           0.675
#   Last ensemble lnprob :  avg: -22.496, max: -20.990
#
# Progress of the run: 65 percent (26 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18            3.06
#   Last ensemble std    :     0.0734          0.0565           0.624
#   Last ensemble lnprob :  avg: -22.634, max: -20.948
#
# Progress of the run: 70 percent (28 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18            3.08
#   Last ensemble std    :     0.0706          0.0568           0.55
#   Last ensemble lnprob :  avg: -22.406, max: -20.984
#
# Progress of the run: 75 percent (30 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18            3.09
#   Last ensemble std    :     0.0732          0.0567           0.862
#   Last ensemble lnprob :  avg: -22.526, max: -20.933
#
# Progress of the run: 80 percent (32 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18             3.1
#   Last ensemble std    :     0.0803          0.0572           0.953
#   Last ensemble lnprob :  avg: -22.450, max: -20.997
#
# Progress of the run: 85 percent (34 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18            3.09
#   Last ensemble std    :     0.0733          0.0495           1.09
#   Last ensemble lnprob :  avg: -22.507, max: -20.979
#
# Progress of the run: 90 percent (36 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18            3.07
#   Last ensemble std    :     0.0736          0.0494           1.13
#   Last ensemble lnprob :  avg: -22.528, max: -20.952
#
# Progress of the run: 95 percent (38 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.1            3.18            3.06
#   Last ensemble std    :     0.0724          0.0503           1.11
#   Last ensemble lnprob :  avg: -22.543, max: -21.002
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $28.14^{+0.08}_{-0.06}$
#                  norm = $(1.39^{+0.3}_{-0.19})\times10^{28}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $3.17 \pm 0.06$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $3.1 \pm 0.3$
#                  cutoff = $(1.2^{+0.9}_{-0.6})\times10^{3}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Model output 0... [naima.analysis]
# /Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/site-packages/naima/analysis.py:153: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Model output 1: cannot convert float NaN to integer [naima.analysis]
# WARNING: "cl" keyword not provided in input data table, upper limits will be assumed to be at 90% confidence level [naima.utils]
# INFO: Plotting Model output 1... [naima.analysis]
# INFO: Saving results table in ../fit_results/RSOph/leptonic_model/fit_naima_results_all_day3_results.ecsv [naima.analysis]
#
#
# day 4
# INFO: Launching interactive model fitter, close when finished [naima.core]
# Figure(640x480)
# INFO: Finding Maximum Likelihood parameters through Nelder-Mead fitting... [naima.core]
# INFO:    Initial parameters: [29.87531616  2.5         2.30103   ] [naima.core]
# INFO:    Initial lnprob(p0): -9178.748 [naima.core]
# INFO:    New ML parameters : [28.42940772  3.1519856   3.16743865] [naima.core]
# INFO:    Maximum lnprob(p0): -16.001 [naima.core]
# Burning in the 50 walkers with 50 steps...
#
# Progress of the run: 0 percent (0 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.15            3.17
#   Last ensemble std    :      0.124          0.0159          0.0157
#   Last ensemble lnprob :  avg: -23.589, max: -16.576
#
# Progress of the run: 10 percent (5 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.15            3.17
#   Last ensemble std    :     0.0754          0.0273          0.0223
#   Last ensemble lnprob :  avg: -19.868, max: -16.049
#
# Progress of the run: 20 percent (10 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.16            3.17
#   Last ensemble std    :     0.0518          0.0502          0.0672
#   Last ensemble lnprob :  avg: -18.750, max: -16.049
#
# Progress of the run: 30 percent (15 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.15            3.18
#   Last ensemble std    :     0.0465          0.0624          0.0927
#   Last ensemble lnprob :  avg: -18.365, max: -16.187
#
# Progress of the run: 40 percent (20 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.16            3.18
#   Last ensemble std    :     0.0466          0.0638           0.134
#   Last ensemble lnprob :  avg: -18.275, max: -16.228
#
# Progress of the run: 50 percent (25 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.15            3.18
#   Last ensemble std    :     0.0515          0.0688           0.191
#   Last ensemble lnprob :  avg: -18.571, max: -16.092
#
# Progress of the run: 60 percent (30 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.17            3.19
#   Last ensemble std    :     0.0657          0.0688           0.352
#   Last ensemble lnprob :  avg: -18.437, max: -16.293
#
# Progress of the run: 70 percent (35 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.15            3.19
#   Last ensemble std    :     0.0742          0.0696           0.413
#   Last ensemble lnprob :  avg: -18.281, max: -16.674
#
# Progress of the run: 80 percent (40 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.17            3.28
#   Last ensemble std    :     0.0688          0.0695           0.44
#   Last ensemble lnprob :  avg: -18.389, max: -16.067
#
# Progress of the run: 90 percent (45 of 50 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.26
#   Last ensemble std    :     0.0649          0.0589           0.431
#   Last ensemble lnprob :  avg: -17.825, max: -16.206
#
# Walker burn in finished, running 40 steps...
#
# Progress of the run: 0 percent (0 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.46
#   Last ensemble std    :     0.0585           0.058           0.471
#   Last ensemble lnprob :  avg: -17.633, max: -16.432
#
# Progress of the run: 5 percent (2 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.18            3.33
#   Last ensemble std    :     0.0606          0.0639           0.573
#   Last ensemble lnprob :  avg: -17.860, max: -16.303
#
# Progress of the run: 10 percent (4 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.42
#   Last ensemble std    :     0.0711          0.0714           0.636
#   Last ensemble lnprob :  avg: -18.012, max: -16.218
#
# Progress of the run: 15 percent (6 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.18            3.39
#   Last ensemble std    :     0.0705          0.0703           0.626
#   Last ensemble lnprob :  avg: -17.915, max: -16.243
#
# Progress of the run: 20 percent (8 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.18            3.39
#   Last ensemble std    :     0.0642          0.0651           0.622
#   Last ensemble lnprob :  avg: -17.777, max: -16.264
#
# Progress of the run: 25 percent (10 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.18            3.35
#   Last ensemble std    :     0.0682           0.07            0.626
#   Last ensemble lnprob :  avg: -17.938, max: -16.241
#
# Progress of the run: 30 percent (12 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.18            3.39
#   Last ensemble std    :     0.0665          0.0672           0.571
#   Last ensemble lnprob :  avg: -17.899, max: -16.215
#
# Progress of the run: 35 percent (14 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.18             3.4
#   Last ensemble std    :     0.0696          0.0675           0.597
#   Last ensemble lnprob :  avg: -17.911, max: -16.186
#
# Progress of the run: 40 percent (16 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.31
#   Last ensemble std    :     0.0663          0.0679           0.559
#   Last ensemble lnprob :  avg: -18.030, max: -16.215
#
# Progress of the run: 45 percent (18 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.32
#   Last ensemble std    :     0.0715           0.071           0.627
#   Last ensemble lnprob :  avg: -17.968, max: -16.163
#
# Progress of the run: 50 percent (20 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4             3.2             3.4
#   Last ensemble std    :     0.0734          0.0707           0.663
#   Last ensemble lnprob :  avg: -17.913, max: -16.163
#
# Progress of the run: 55 percent (22 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.43
#   Last ensemble std    :     0.0732          0.0769           0.746
#   Last ensemble lnprob :  avg: -18.069, max: -16.459
#
# Progress of the run: 60 percent (24 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.38
#   Last ensemble std    :     0.0704           0.072           0.873
#   Last ensemble lnprob :  avg: -18.050, max: -16.459
#
# Progress of the run: 65 percent (26 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4             3.2            3.41
#   Last ensemble std    :     0.0688          0.0727           1.03
#   Last ensemble lnprob :  avg: -18.084, max: -16.430
#
# Progress of the run: 70 percent (28 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.45
#   Last ensemble std    :     0.0611          0.0732           0.846
#   Last ensemble lnprob :  avg: -17.821, max: -16.194
#
# Progress of the run: 75 percent (30 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.18            3.49
#   Last ensemble std    :     0.0634           0.079           0.834
#   Last ensemble lnprob :  avg: -17.733, max: -16.194
#
# Progress of the run: 80 percent (32 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4            3.19            3.56
#   Last ensemble std    :      0.063          0.0767           0.789
#   Last ensemble lnprob :  avg: -17.906, max: -16.230
#
# Progress of the run: 85 percent (34 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4             3.2            3.67
#   Last ensemble std    :     0.0655          0.0805           0.849
#   Last ensemble lnprob :  avg: -17.918, max: -16.258
#
# Progress of the run: 90 percent (36 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4             3.2            3.69
#   Last ensemble std    :      0.059          0.0754           0.866
#   Last ensemble lnprob :  avg: -17.730, max: -16.258
#
# Progress of the run: 95 percent (38 of 40 steps)
#                            --log10(norm)-- -----index----- -log10(cutoff)-
#   Last ensemble median :      28.4             3.2            3.73
#   Last ensemble std    :     0.0599          0.0755           0.832
#   Last ensemble lnprob :  avg: -17.690, max: -16.337
# INFO: Plotting chain of parameter log10(norm)... [naima.analysis]
# INFO: -------------------log10(norm)--------------------
#           log10(norm) = $28.41 \pm 0.07$
#                  norm = $(2.5^{+0.5}_{-0.4})\times10^{28}$ [naima.plot]
# INFO: Plotting chain of parameter index... [naima.analysis]
# INFO: ----------------------index-----------------------
#           index = $3.19 \pm 0.08$ [naima.plot]
# INFO: Plotting chain of parameter log10(cutoff)... [naima.analysis]
# INFO: ------------------log10(cutoff)-------------------
#           log10(cutoff) = $3.4^{+0.7}_{-0.4}$
#                  cutoff = $(2.7^{+12}_{-1.7})\times10^{3}$ [naima.plot]
# INFO: Plotting corner plot... [naima.analysis]
# INFO: Plotting Model output 0... [naima.analysis]
# /Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/site-packages/naima/analysis.py:153: UserWarning: Attempt to set non-positive xlim on a log-scaled axis will be ignored.
#   f.clf()
# WARNING: plot_blob failed for Model output 1: cannot convert float NaN to integer [naima.analysis]
# Exception ignored in: <function Pool.__del__ at 0x14d5131a0>
# Traceback (most recent call last):
#   File "/Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/multiprocessing/pool.py", line 271, in __del__
#   File "/Users/aaguasca/anaconda3/envs/naima_handson/lib/python3.11/multiprocessing/queues.py", line 371, in put
# AttributeError: 'NoneType' object has no attribute 'dumps'
# INFO: Plotting Model output 1... [naima.analysis]
# INFO: Saving results table in ../fit_results/RSOph/leptonic_model/fit_naima_results_all_day4_results.ecsv [naima.analysis]
# CompletedProcess(args=['python', '../fit_results/RSOph/leptonic_model/RSOph_leptonic.py'], returncode=0)

# %% [markdown]
# We do the same steps as in the hadronic case to access the results and show the gamma-ray emission of the best-fit models

# %%
# Load results
tabs_leptonic=[]
for day in [1,2,3,4]:
    tab=Table.read(f"../fit_results/RSOph/leptonic_model/fit_naima_results_all_day{day}_results.ecsv")
    tabs_leptonic.append(tab)

# %%
display(tabs_leptonic[0])
# Out:
# <Table length=6>
#     label             median                unc_lo                 unc_hi
#     str13            float64               float64                float64
# ------------- --------------------- ---------------------- ---------------------
#   log10(norm)    27.840768579819517     0.3068645228337701     0.346757833000499
#          norm 6.930572826530743e+27 3.5115338074550567e+27 8.469630494691161e+27
#         index    2.6513549492869046    0.21061862191148473   0.19878035530882254
# log10(cutoff)     1.746948078146755    0.17161663041248487    0.1939338113489999
#        cutoff     55.84034311111783      18.22790832656655    31.433055671397426
#         blob1                   nan                    nan                   nan

# %%
# You can also load the hdf5 files
runs_leptonic=[]
for day in [1,2,3,4]:
    file=f"../fit_results/RSOph/leptonic_model/fit_naima_results_all_day{day}.hdf5"
    run=naima.read_run(file, modelfn=None)
    runs_leptonic.append(run)
# naima.plot_corner(runs_leptonic[0]);
# naima.plot_chain(runs_leptonic[0],0);

# %%
#Day 1
# Create the particle energy distribution using the best-fit values
particle_distribution_day1 = naima.models.ExponentialCutoffPowerLaw(
    tabs_leptonic[0]["median"][1]*u.Unit('1/eV'), 
    130.0 * u.GeV, 
    tabs_leptonic[0]["median"][2], 
    tabs_leptonic[0]["median"][4]*u.GeV
)
# Create the radiative model
radiative_model_day1 = naima.models.InverseCompton(
    particle_distribution_day1, 
    seed_photon_fields=[
        "CMB",
        ["photosphere", 10780*u.K,0.14*((10780/8460)**4/(1/3)**2)*u.Unit("erg cm-3")]
    ]
)

#Day 2
particle_distribution_day2 = naima.models.ExponentialCutoffPowerLaw(
    tabs_leptonic[1]["median"][1]*u.Unit('1/eV'), 
    130.0 * u.GeV, 
    tabs_leptonic[1]["median"][2], 
    tabs_leptonic[1]["median"][4]*u.GeV
)
radiative_model_day2 = naima.models.InverseCompton(
    particle_distribution_day2, 
    seed_photon_fields=[
        "CMB",
        ["photosphere", 9500*u.K,0.14*((9500/8460)**4/(2/3)**2)*u.Unit("erg cm-3")]
    ]
)

#Day 3
particle_distribution_day3 = naima.models.ExponentialCutoffPowerLaw(
    tabs_leptonic[2]["median"][1]*u.Unit('1/eV'), 
    130.0 * u.GeV, 
    tabs_leptonic[2]["median"][2], 
    tabs_leptonic[2]["median"][4]*u.GeV
)
radiative_model_day3 = naima.models.InverseCompton(
    particle_distribution_day3, 
    seed_photon_fields=[
        "CMB",
        ["photosphere", 8460*u.K,0.14*((8460/8460)**4/(3/3)**2)*u.Unit("erg cm-3")]
    ]
)

#Day 4
particle_distribution_day4 = naima.models.ExponentialCutoffPowerLaw(
    tabs_leptonic[3]["median"][1]*u.Unit('1/eV'), 
    130.0 * u.GeV, 
    tabs_leptonic[3]["median"][2], 
    tabs_leptonic[3]["median"][4]*u.GeV
)
radiative_model_day4 = naima.models.InverseCompton(
    particle_distribution_day4, 
    seed_photon_fields=[
        "CMB",
        ["photosphere", 7680*u.K,0.14*((7680/8460)**4/(4/3)**2)*u.Unit("erg cm-3")]
    ]
)

# %%
from fit_results.RSOph.leptonic_model.RSOph_leptonic import ICmodel

photon_energy=np.geomspace(0.00006, 2.6,100)*u.TeV

with quantity_support():
    for ii,(day,data,rad_model) in enumerate(
        zip(
            [1,2,3,4],
            daily_data,
            [radiative_model_day1,radiative_model_day2,radiative_model_day3,radiative_model_day4]
        )
    ):

        fig=naima.plot_data(data, e_unit=u.GeV)
        ax = fig.axes[0]
        ax.set_title(f"Day {day} after eruption")

        ax.xaxis.units = u.GeV
        ax.yaxis.units = u.Unit("erg s-1 cm-2")
        ymin, ymax = ax.get_ylim()
        xmin, xmax = ax.get_xlim()
        
        plt.loglog(
            photon_energy,
            rad_model.sed(photon_energy,distance=2.45 * u.kpc),
            color="k",
            label=r"Best-fit (IC)"
        )

        IC_func=ICmodel(day)
        for i in range(min(np.shape(runs_leptonic[ii].get_chain())[1],100)):            
            photon_energy=np.geomspace(xmin,xmax,100)*u.GeV
            flux=IC_func.IC(runs_leptonic[ii].get_chain()[-1,i,:],data=photon_energy)
            # SED := E**2 * differential flux (d\phi/dE)
            plt.loglog(photon_energy,photon_energy**2*flux,color="gray",alpha=0.1)

        ax.set_ylim((ymin, ymax))
        ax.set_ylabel(f"E$^2$ d$\phi$/dE (erg cm$^{{-2}}$ s$^{{-1}}$)")
        ax.set_xlabel(f"Energy (GeV)")    
        ax.legend()
